# %%
import pandas as pd

# %%
combined_df = pd.read_csv("combined_df.csv")

# %%
combined_df.sample(10)
# Out:
#      Unnamed: 0          Cities  Population  Elevation  AQI   Latitude  \
# 98           98        Katowice    317316.0      266.0   69  50.264611
# 353         353      Pingxiang     372123.0      167.0   72  27.622768
# 21           21           Lagos   9000000.0       11.0   60   6.440483
# 218         218           Thane   1261517.0       23.0  162  19.137500
# 369         369         Huaibei    903039.0       51.0  155  33.955845
# 415         415           Qixia     79106.0      135.0   87  37.306944
# 26           26        Dongguan   8000000.0        1.0   70  23.020536
# 145         145          Urumqi   3029372.0      862.0  150  43.825645
# 358         358  Port Elizabeth    967677.0       75.0   91 -33.985586
# 102         102          Nagpur   2228018.0      319.0  152  21.152875
#
#       Longitude   PM25   PM10    O3
# 98    18.975028   69.0   22.0  14.0
# 353  113.854556   99.0   28.0   5.0
# 21     3.406815   57.0  150.0   2.0
# 218   72.915056  172.0   58.0  18.0
# 369  116.798265  152.0   46.0   3.0
# 415  120.836944  158.0   19.0   9.0
# 26   113.751765   82.0   28.0   8.0
# 145   87.616823  151.0   33.0   2.0
# 358   25.588500   41.0    8.0   7.0
# 102   79.051753  142.0   58.0  19.0

# %%
combined_df['Population'].max()
# Out:
# 22315474.0

# %%
aqi = combined_df['AQI']
population = combined_df['Population']
elevation = combined_df['Elevation']
pm25 = combined_df['PM25']
pm10 = combined_df['PM10']
o3 = combined_df['O3']

# %%
import matplotlib.pyplot as plt

# %%
#create Figure 1: AQI vs Population
plt.scatter(aqi, population, color = "#BF4D27")
plt.xlabel("Air Quality Index")
plt.ylabel("Population (in tens of millions)")
plt.title("Figure 1")
font = {'size'   : 18, 'family': "Times New Roman","sans-serif":"Arial"}
plt.rc('font', **font)

# %%
#create Figure 2: AQI vs Elevation
plt.scatter(aqi, elevation, color = "#4F7B28")
plt.xlabel("Air Quality Index")
plt.ylabel("Elevation (ft)")
plt.title("Figure 2")
font = {'size'   : 18, 'family': "Times New Roman","sans-serif":"Arial"}
plt.rc('font', **font)

# %%
#create Figure 3: AQI vs PM25
plt.scatter(aqi, pm25, color = "#28767B")
plt.xlabel("Air Quality Index")
plt.ylabel("PM25 (µg/m³)")
plt.title("Figure 3")
font = {'size'   : 18, 'family': "Times New Roman","sans-serif":"Arial"}
plt.rc('font', **font)

# %%
#create Figure 4: AQI vs PM10
plt.scatter(aqi, pm10, color = "#28397B")
plt.xlabel("Air Quality Index")
plt.ylabel("PM10 Levels (µg/m³)")
plt.title("Figure 4")
font = {'size'   : 18, 'family': "Times New Roman","sans-serif":"Arial"}
plt.rc('font', **font)

# %%
#create Figure 5: AQI vs O3
plt.scatter(aqi, o3, color = "#63287B")
plt.xlabel("Air Quality Index")
plt.ylabel("O3 Levels")
plt.title("Figure 5")
font = {'size'   : 18, 'family': "Times New Roman","sans-serif":"Arial"}
plt.rc('font', **font)
